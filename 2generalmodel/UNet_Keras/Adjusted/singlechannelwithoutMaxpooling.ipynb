# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %%
##迭代器################################

from tensorflow.compat.v1 import keras

from __future__ import print_function

import numpy as np 
import os
import skimage.io as io
import matplotlib.pyplot as plt

import skimage.transform as trans

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from tensorflow.compat.v1.keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, concatenate, UpSampling2D

IMG_SIZE = 224
IMG_BANDS = 3
# =============================================================================
# ##这一步获取了原图和mask
def trainGenerator(batch_size,train_path,train_path2,image_folder,mask_folder,aug_dict,
                    flag_multi_class, num_class ,image_color_mode = 'rgb',#"grayscale",
                    mask_color_mode = "grayscale",image_save_prefix  = "image",mask_save_prefix  = "mask",save_to_dir = None,target_size = (IMG_SIZE,IMG_SIZE),seed = 1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    image_generator = image_datagen.flow_from_directory(
        train_path,
        classes = [image_folder],
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)
    print(image_generator)
    mask_generator = mask_datagen.flow_from_directory(
        train_path2,
        classes = [mask_folder],
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)
    train_generator = zip(image_generator, mask_generator)
    new_mask = np.ones([batch_size,224,224,2])
    for (img,mask) in train_generator:
        #img = img / 255
        #print('mask',mask.shape)
        img,mask = adjustData(img,mask,
                           flag_multi_class,   ##参数（flag_multi_class）用来开启多分类
                           num_class,new_mask)##这里对图像进行了处理，用以减小计算量（函数定义在下面）
        yield (img,mask)##用生成器进行迭代数据，可以传入model.fit_generator（）这个函数进行训练
        new_mask = np.ones([batch_size,224,224,2])
#    return img, mask

def adjustData(img,mask,flag_multi_class,num_class,new_mask):
    if (flag_multi_class):#如果多分类，在mask添加多层，每层对应一个类别
        img = img / 255
    return (img,mask)


# =============================================================================

# %%
img_path = '/content/drive/MyDrive/2105Dinghu/data/v2/train/'
mask_path = '/content/drive/MyDrive/2105Dinghu/data/v2/train/'
img_files = 'td_crop'
mask_files = 'mask_crop'
num_class = {'0','1'}


data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest')
myGene = trainGenerator(2,img_path,         #图像路径
                            mask_path,    #mask路径
                            img_files,      #mask文件夹名称
                            mask_files,     #图像文件夹名称（不懂的话看此函数定义和keras文档）
                            data_gen_args,True,#
                            num_class,target_size=(IMG_SIZE,IMG_SIZE))

img_valid_path = '/content/drive/MyDrive/2105Dinghu/data/v2/valid/'
mask_valid_path = '/content/drive/MyDrive/2105Dinghu/data/v2/valid/'
valid_img_files = 'td_crop'
valid_mask_files = 'mask_crop'
valid_data = trainGenerator(2,img_valid_path,         #图像路径
                            mask_valid_path,    #mask路径
                            valid_img_files,      #mask文件夹名称
                            valid_mask_files,     #图像文件夹名称（不懂的话看此函数定义和keras文档）
                            data_gen_args,True,#
                            num_class,target_size=(IMG_SIZE,IMG_SIZE))

# %%
TARGET_SIZE = 224
BANDS = 3
def unet_test(pretrained_weights = None,input_size = (TARGET_SIZE, TARGET_SIZE, BANDS)):
    # input layer
    # 224 224 
    inputs = Input(input_size)

    # Conv 1
    conv1 = Conv2D(64, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(64, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    down_conv1 = Conv2D(64, kernel_size=(3,3), strides=2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    # 112 112

    # Conv 2
    conv2 = Conv2D(128, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(down_conv1)
    conv2 = Conv2D(128, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    down_conv2 = Conv2D(128, kernel_size=(3,3), strides=2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    # 56 56

    # Conv 3
    conv3 = Conv2D(256, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(down_conv2)
    conv3 = Conv2D(256, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    drop3 = Dropout(0.7)(conv3)
    down_conv3 = Conv2D(256, kernel_size=(3,3), strides=2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    # 28 28

    # Conv 4
    conv4 = Conv2D(512, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(down_conv3)
    conv4 = Conv2D(512, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = Conv2D(512, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    drop4 = Dropout(0.7)(conv4)
    down_conv4 = Conv2D(512, kernel_size=(3,3), strides=2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    # 14 14
    
    #===================================================#
    # Bridge layer
    conv5 = Conv2D(1024, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(down_conv4)
    conv5 = Conv2D(1024, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = Conv2D(1024, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    drop5 = Dropout(0.5)(conv5)
    down_conv5 = Conv2D(1024, kernel_size=(3,3), strides=2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    # 7 7     
    #===================================================#
    
    # Up 4
    up6 = Conv2D(1024, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(down_conv5))
    # 14 14
    merge6 = concatenate([down_conv4,up6],)
    conv6 = Conv2D(1024, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(1024, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    
    # Up 3
    up7 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    # 28 28
    merge7 = concatenate([down_conv3,up7],)
    conv7 = Conv2D(512, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(512, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    # Up 2
    up8 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    # 56 56
    merge8 = concatenate([down_conv2,up8], axis = 3)
    conv8 = Conv2D(256, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(256, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

    # Up 1
    up9 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    # 112 112
    merge9 = concatenate([down_conv1,up9], axis = 3)
    conv9 = Conv2D(128, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(128, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)

    up10 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv9))
    # 224 224

    # final layer
    conv10 = Conv2D(64, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(up10)
    conv11 = Conv2D(8, kernel_size=(3,3), strides=1, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv10)
    conv12 = Conv2D(1, 1, activation = 'sigmoid', name = 'result')(conv11) ##注意output层
                                                         
    model = Model(inputs = inputs, outputs = conv12)

    model.compile(optimizer = Adam(lr = 1e-5), loss = 'binary_crossentropy', metrics = ['accuracy']) #Adam(lr = 1e-5)
    
    #model.summary()

    if(pretrained_weights):
    	model.load_weights(pretrained_weights)

    return model
# =============================================================================
model = unet_test()
#model_checkpoint = ModelCheckpoint('saver\module_1.hdf5', monitor='loss',verbose=1, save_best_only=True)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 224, 224, 64) 1792        input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 224, 224, 64) 36928       conv2d_64[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 112, 112, 64) 36928       conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 112, 112, 128 73856       conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 112, 112, 128 147584      conv2d_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 56, 56, 128)  147584      conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 56, 56, 256)  295168      conv2d_69[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_70[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 28, 28, 256)  590080      conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 28, 28, 512)  1180160     conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 28, 28, 512)  2359808     conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 28, 28, 512)  2359808     conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 14, 14, 512)  2359808     conv2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 14, 14, 1024) 4719616     conv2d_76[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 14, 14, 1024) 9438208     conv2d_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 14, 14, 1024) 9438208     conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 7, 7, 1024)   9438208     conv2d_79[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_10 (UpSampling2D) (None, 14, 14, 1024) 0           conv2d_80[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 14, 14, 1024) 4195328     up_sampling2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 14, 14, 1536) 0           conv2d_76[0][0]
#                                                                  conv2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 14, 14, 1024) 14156800    concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 14, 14, 1024) 9438208     conv2d_82[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 28, 28, 1024) 0           conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 28, 28, 512)  2097664     up_sampling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 28, 28, 768)  0           conv2d_72[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 28, 28, 512)  3539456     concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 28, 28, 512)  2359808     conv2d_85[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 56, 56, 512)  0           conv2d_86[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 56, 56, 256)  524544      up_sampling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 56, 56, 384)  0           conv2d_69[0][0]
#                                                                  conv2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 56, 56, 256)  884992      concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_88[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 112, 112, 256 0           conv2d_89[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 112, 112, 128 131200      up_sampling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 112, 112, 192 0           conv2d_66[0][0]
#                                                                  conv2d_90[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 112, 112, 128 221312      concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 112, 112, 128 147584      conv2d_91[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 224, 224, 128 0           conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 224, 224, 64) 32832       up_sampling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 224, 224, 64) 36928       conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 224, 224, 8)  4616        conv2d_94[0][0]
# __________________________________________________________________________________________________
# result (Conv2D)                 (None, 224, 224, 1)  9           conv2d_95[0][0]
# ==================================================================================================
# Total params: 81,575,185
# Trainable params: 81,575,185
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
#存储loss和acc
import matplotlib.pyplot as plt
import keras
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]}

    def on_batch_end(self, batch, logs={}):
        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('acc'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_acc'))

    def on_epoch_end(self, batch, logs={}):
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('acc'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_acc'))

    def loss_plot(self, loss_type):
        iters = range(len(self.losses[loss_type]))
        plt.figure()
        # acc
        #plt.plot(iters, self.accuracy[loss_type], 'r', label='train acc')
        # loss
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_acc
            #plt.plot(iters, self.val_acc[loss_type], 'b', label='val acc')
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('loss')
        plt.legend(loc="upper right")
        plt.show()

# %%
#显示损失曲线
history = LossHistory()
model.fit_generator(myGene,steps_per_epoch=10,epochs=500,callbacks=[history],validation_data = valid_data, validation_steps = 10) #epoch循环次数
#acc-loss曲线绘制
history.loss_plot('epoch')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:1228: UserWarning: `model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`model.fit_generator` is deprecated and '
# Found 39 images belonging to 1 classes.
# <keras.preprocessing.image.DirectoryIterator object at 0x7f96e00c2fd0>
# Found 39 images belonging to 1 classes.
# Epoch 1/500
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.7261 - accuracy: 0.5478Found 9 images belonging to 1 classes.
# <keras.preprocessing.image.DirectoryIterator object at 0x7f969adcca50>
# Found 9 images belonging to 1 classes.
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 10/10 [==============================] - 54s 2s/step - batch: 4.5000 - size: 2.0000 - loss: 0.7261 - accuracy: 0.5478 - val_loss: 0.6974 - val_accuracy: 0.4392
# Epoch 2/500
# 10/10 [==============================] - 9s 965ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.6620 - accuracy: 0.5831 - val_loss: 0.6260 - val_accuracy: 0.7160
# Epoch 3/500
# 10/10 [==============================] - 7s 744ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.6176 - accuracy: 0.7318 - val_loss: 0.6033 - val_accuracy: 0.7613
# Epoch 4/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.5795 - accuracy: 0.7778 - val_loss: 0.5930 - val_accuracy: 0.7494
# Epoch 5/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.5175 - accuracy: 0.7975 - val_loss: 0.5037 - val_accuracy: 0.7633
# Epoch 6/500
# 10/10 [==============================] - 7s 723ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.4721 - accuracy: 0.7657 - val_loss: 0.6069 - val_accuracy: 0.6331
# Epoch 7/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.5066 - accuracy: 0.7271 - val_loss: 0.4010 - val_accuracy: 0.7976
# Epoch 8/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.4110 - accuracy: 0.7913 - val_loss: 0.3870 - val_accuracy: 0.8236
# Epoch 9/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.3586 - accuracy: 0.8311 - val_loss: 0.4215 - val_accuracy: 0.8152
# Epoch 10/500
# 10/10 [==============================] - 7s 716ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.3908 - accuracy: 0.8239 - val_loss: 0.3411 - val_accuracy: 0.8396
# Epoch 11/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.3082 - accuracy: 0.8707 - val_loss: 0.3200 - val_accuracy: 0.8374
# Epoch 12/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.3349 - accuracy: 0.8443 - val_loss: 0.4181 - val_accuracy: 0.7783
# Epoch 13/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.3636 - accuracy: 0.8236 - val_loss: 0.3797 - val_accuracy: 0.8113
# Epoch 14/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.3372 - accuracy: 0.8386 - val_loss: 0.3147 - val_accuracy: 0.8675
# Epoch 15/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2458 - accuracy: 0.8965 - val_loss: 0.2742 - val_accuracy: 0.8836
# Epoch 16/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.3367 - accuracy: 0.8509 - val_loss: 0.2667 - val_accuracy: 0.8801
# Epoch 17/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2499 - accuracy: 0.8973 - val_loss: 0.2224 - val_accuracy: 0.8968
# Epoch 18/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.2625 - accuracy: 0.8859 - val_loss: 0.2390 - val_accuracy: 0.8916
# Epoch 19/500
# 10/10 [==============================] - 7s 737ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2736 - accuracy: 0.8827 - val_loss: 0.2461 - val_accuracy: 0.8900
# Epoch 20/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.2744 - accuracy: 0.8763 - val_loss: 0.2334 - val_accuracy: 0.8978
# Epoch 21/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2782 - accuracy: 0.8866 - val_loss: 0.2171 - val_accuracy: 0.9044
# Epoch 22/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.2022 - accuracy: 0.9080 - val_loss: 0.3177 - val_accuracy: 0.8501
# Epoch 23/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2688 - accuracy: 0.8796 - val_loss: 0.2446 - val_accuracy: 0.8920
# Epoch 24/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1977 - accuracy: 0.9232 - val_loss: 0.2265 - val_accuracy: 0.9128
# Epoch 25/500
# 10/10 [==============================] - 7s 736ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2148 - accuracy: 0.9152 - val_loss: 0.2284 - val_accuracy: 0.9062
# Epoch 26/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1869 - accuracy: 0.9211 - val_loss: 0.2319 - val_accuracy: 0.8990
# Epoch 27/500
# 10/10 [==============================] - 7s 736ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1951 - accuracy: 0.9152 - val_loss: 0.2134 - val_accuracy: 0.9102
# Epoch 28/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.2219 - accuracy: 0.9075 - val_loss: 0.3100 - val_accuracy: 0.8726
# Epoch 29/500
# 10/10 [==============================] - 7s 737ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2329 - accuracy: 0.8984 - val_loss: 0.2361 - val_accuracy: 0.8939
# Epoch 30/500
# 10/10 [==============================] - 7s 716ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1779 - accuracy: 0.9217 - val_loss: 0.2191 - val_accuracy: 0.9026
# Epoch 31/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1733 - accuracy: 0.9285 - val_loss: 0.2142 - val_accuracy: 0.9108
# Epoch 32/500
# 10/10 [==============================] - 7s 717ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1757 - accuracy: 0.9205 - val_loss: 0.1932 - val_accuracy: 0.9112
# Epoch 33/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1603 - accuracy: 0.9281 - val_loss: 0.1994 - val_accuracy: 0.9098
# Epoch 34/500
# 10/10 [==============================] - 7s 717ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1883 - accuracy: 0.9235 - val_loss: 0.1787 - val_accuracy: 0.9187
# Epoch 35/500
# 10/10 [==============================] - 7s 737ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1722 - accuracy: 0.9253 - val_loss: 0.2083 - val_accuracy: 0.9124
# Epoch 36/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1722 - accuracy: 0.9255 - val_loss: 0.2001 - val_accuracy: 0.9107
# Epoch 37/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1925 - accuracy: 0.9143 - val_loss: 0.2369 - val_accuracy: 0.8991
# Epoch 38/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1574 - accuracy: 0.9313 - val_loss: 0.1845 - val_accuracy: 0.9206
# Epoch 39/500
# 10/10 [==============================] - 7s 737ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1498 - accuracy: 0.9350 - val_loss: 0.2049 - val_accuracy: 0.9113
# Epoch 40/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1652 - accuracy: 0.9239 - val_loss: 0.1810 - val_accuracy: 0.9232
# Epoch 41/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1880 - accuracy: 0.9176 - val_loss: 0.1795 - val_accuracy: 0.9215
# Epoch 42/500
# 10/10 [==============================] - 7s 717ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1545 - accuracy: 0.9342 - val_loss: 0.1695 - val_accuracy: 0.9240
# Epoch 43/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1377 - accuracy: 0.9381 - val_loss: 0.1680 - val_accuracy: 0.9196
# Epoch 44/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1631 - accuracy: 0.9256 - val_loss: 0.1816 - val_accuracy: 0.9255
# Epoch 45/500
# 10/10 [==============================] - 7s 737ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1333 - accuracy: 0.9417 - val_loss: 0.1723 - val_accuracy: 0.9194
# Epoch 46/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1544 - accuracy: 0.9313 - val_loss: 0.1828 - val_accuracy: 0.9198
# Epoch 47/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1257 - accuracy: 0.9455 - val_loss: 0.1868 - val_accuracy: 0.9195
# Epoch 48/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1618 - accuracy: 0.9269 - val_loss: 0.2023 - val_accuracy: 0.9207
# Epoch 49/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1489 - accuracy: 0.9360 - val_loss: 0.1900 - val_accuracy: 0.9163
# Epoch 50/500
# 10/10 [==============================] - 7s 717ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1436 - accuracy: 0.9336 - val_loss: 0.1698 - val_accuracy: 0.9202
# Epoch 51/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1423 - accuracy: 0.9345 - val_loss: 0.1615 - val_accuracy: 0.9240
# Epoch 52/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1429 - accuracy: 0.9365 - val_loss: 0.1921 - val_accuracy: 0.9187
# Epoch 53/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1471 - accuracy: 0.9341 - val_loss: 0.2030 - val_accuracy: 0.9127
# Epoch 54/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1284 - accuracy: 0.9412 - val_loss: 0.1704 - val_accuracy: 0.9256
# Epoch 55/500
# 10/10 [==============================] - 7s 737ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1272 - accuracy: 0.9430 - val_loss: 0.1716 - val_accuracy: 0.9244
# Epoch 56/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1379 - accuracy: 0.9380 - val_loss: 0.2549 - val_accuracy: 0.9001
# Epoch 57/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1766 - accuracy: 0.9218 - val_loss: 0.1713 - val_accuracy: 0.9196
# Epoch 58/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1473 - accuracy: 0.9323 - val_loss: 0.2484 - val_accuracy: 0.9060
# Epoch 59/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1227 - accuracy: 0.9475 - val_loss: 0.1747 - val_accuracy: 0.9198
# Epoch 60/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1687 - accuracy: 0.9227 - val_loss: 0.1451 - val_accuracy: 0.9337
# Epoch 61/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1300 - accuracy: 0.9418 - val_loss: 0.1700 - val_accuracy: 0.9252
# Epoch 62/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1318 - accuracy: 0.9388 - val_loss: 0.1552 - val_accuracy: 0.9318
# Epoch 63/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1183 - accuracy: 0.9462 - val_loss: 0.1615 - val_accuracy: 0.9340
# Epoch 64/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1301 - accuracy: 0.9342 - val_loss: 0.1859 - val_accuracy: 0.9243
# Epoch 65/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1198 - accuracy: 0.9446 - val_loss: 0.1773 - val_accuracy: 0.9209
# Epoch 66/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1364 - accuracy: 0.9397 - val_loss: 0.1793 - val_accuracy: 0.9214
# Epoch 67/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1022 - accuracy: 0.9553 - val_loss: 0.1784 - val_accuracy: 0.9195
# Epoch 68/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1317 - accuracy: 0.9356 - val_loss: 0.1881 - val_accuracy: 0.9195
# Epoch 69/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1057 - accuracy: 0.9490 - val_loss: 0.1792 - val_accuracy: 0.9207
# Epoch 70/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1306 - accuracy: 0.9404 - val_loss: 0.1921 - val_accuracy: 0.9206
# Epoch 71/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1405 - accuracy: 0.9366 - val_loss: 0.1823 - val_accuracy: 0.9212
# Epoch 72/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1296 - accuracy: 0.9420 - val_loss: 0.1694 - val_accuracy: 0.9268
# Epoch 73/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0993 - accuracy: 0.9532 - val_loss: 0.1748 - val_accuracy: 0.9248
# Epoch 74/500
# 10/10 [==============================] - 7s 717ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1303 - accuracy: 0.9407 - val_loss: 0.1667 - val_accuracy: 0.9292
# Epoch 75/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1148 - accuracy: 0.9435 - val_loss: 0.1990 - val_accuracy: 0.9170
# Epoch 76/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1084 - accuracy: 0.9496 - val_loss: 0.1827 - val_accuracy: 0.9224
# Epoch 77/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1099 - accuracy: 0.9504 - val_loss: 0.2338 - val_accuracy: 0.9102
# Epoch 78/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1198 - accuracy: 0.9463 - val_loss: 0.1524 - val_accuracy: 0.9348
# Epoch 79/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0973 - accuracy: 0.9547 - val_loss: 0.1478 - val_accuracy: 0.9349
# Epoch 80/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1219 - accuracy: 0.9403 - val_loss: 0.1687 - val_accuracy: 0.9310
# Epoch 81/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1099 - accuracy: 0.9488 - val_loss: 0.1888 - val_accuracy: 0.9212
# Epoch 82/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0956 - accuracy: 0.9541 - val_loss: 0.1931 - val_accuracy: 0.9224
# Epoch 83/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0980 - accuracy: 0.9528 - val_loss: 0.1606 - val_accuracy: 0.9316
# Epoch 84/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0932 - accuracy: 0.9526 - val_loss: 0.2185 - val_accuracy: 0.9209
# Epoch 85/500
# 10/10 [==============================] - 7s 736ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1034 - accuracy: 0.9512 - val_loss: 0.1661 - val_accuracy: 0.9286
# Epoch 86/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0936 - accuracy: 0.9550 - val_loss: 0.1907 - val_accuracy: 0.9234
# Epoch 87/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1093 - accuracy: 0.9484 - val_loss: 0.1956 - val_accuracy: 0.9294
# Epoch 88/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0938 - accuracy: 0.9558 - val_loss: 0.1444 - val_accuracy: 0.9393
# Epoch 89/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0887 - accuracy: 0.9580 - val_loss: 0.2064 - val_accuracy: 0.9266
# Epoch 90/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1196 - accuracy: 0.9409 - val_loss: 0.1860 - val_accuracy: 0.9210
# Epoch 91/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0903 - accuracy: 0.9581 - val_loss: 0.1761 - val_accuracy: 0.9292
# Epoch 92/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1175 - accuracy: 0.9471 - val_loss: 0.1920 - val_accuracy: 0.9202
# Epoch 93/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1064 - accuracy: 0.9508 - val_loss: 0.1768 - val_accuracy: 0.9238
# Epoch 94/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1393 - accuracy: 0.9318 - val_loss: 0.2740 - val_accuracy: 0.9071
# Epoch 95/500
# 10/10 [==============================] - 7s 736ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1605 - accuracy: 0.9276 - val_loss: 0.1572 - val_accuracy: 0.9330
# Epoch 96/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1262 - accuracy: 0.9420 - val_loss: 0.1614 - val_accuracy: 0.9296
# Epoch 97/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1114 - accuracy: 0.9475 - val_loss: 0.1886 - val_accuracy: 0.9231
# Epoch 98/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1003 - accuracy: 0.9540 - val_loss: 0.1848 - val_accuracy: 0.9211
# Epoch 99/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0906 - accuracy: 0.9567 - val_loss: 0.1858 - val_accuracy: 0.9249
# Epoch 100/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0951 - accuracy: 0.9544 - val_loss: 0.2180 - val_accuracy: 0.9115
# Epoch 101/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1017 - accuracy: 0.9518 - val_loss: 0.2751 - val_accuracy: 0.9038
# Epoch 102/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1080 - accuracy: 0.9494 - val_loss: 0.1788 - val_accuracy: 0.9160
# Epoch 103/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1029 - accuracy: 0.9516 - val_loss: 0.1513 - val_accuracy: 0.9371
# Epoch 104/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0924 - accuracy: 0.9568 - val_loss: 0.1957 - val_accuracy: 0.9335
# Epoch 105/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0982 - accuracy: 0.9513 - val_loss: 0.1809 - val_accuracy: 0.9282
# Epoch 106/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0723 - accuracy: 0.9655 - val_loss: 0.1672 - val_accuracy: 0.9290
# Epoch 107/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0817 - accuracy: 0.9592 - val_loss: 0.1933 - val_accuracy: 0.9272
# Epoch 108/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0758 - accuracy: 0.9635 - val_loss: 0.2210 - val_accuracy: 0.9161
# Epoch 109/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0837 - accuracy: 0.9580 - val_loss: 0.1900 - val_accuracy: 0.9320
# Epoch 110/500
# 10/10 [==============================] - 7s 716ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0840 - accuracy: 0.9609 - val_loss: 0.1715 - val_accuracy: 0.9362
# Epoch 111/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0755 - accuracy: 0.9623 - val_loss: 0.1760 - val_accuracy: 0.9297
# Epoch 112/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0909 - accuracy: 0.9558 - val_loss: 0.2177 - val_accuracy: 0.9260
# Epoch 113/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0885 - accuracy: 0.9550 - val_loss: 0.1850 - val_accuracy: 0.9300
# Epoch 114/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0619 - accuracy: 0.9694 - val_loss: 0.1748 - val_accuracy: 0.9295
# Epoch 115/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0735 - accuracy: 0.9631 - val_loss: 0.1863 - val_accuracy: 0.9304
# Epoch 116/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0789 - accuracy: 0.9602 - val_loss: 0.2646 - val_accuracy: 0.9177
# Epoch 117/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0784 - accuracy: 0.9617 - val_loss: 0.2216 - val_accuracy: 0.9154
# Epoch 118/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0786 - accuracy: 0.9580 - val_loss: 0.2129 - val_accuracy: 0.9215
# Epoch 119/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0706 - accuracy: 0.9648 - val_loss: 0.1926 - val_accuracy: 0.9288
# Epoch 120/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0785 - accuracy: 0.9590 - val_loss: 0.1629 - val_accuracy: 0.9313
# Epoch 121/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0990 - accuracy: 0.9525 - val_loss: 0.2311 - val_accuracy: 0.9295
# Epoch 122/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0826 - accuracy: 0.9606 - val_loss: 0.1839 - val_accuracy: 0.9270
# Epoch 123/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0769 - accuracy: 0.9623 - val_loss: 0.1745 - val_accuracy: 0.9300
# Epoch 124/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0822 - accuracy: 0.9580 - val_loss: 0.2088 - val_accuracy: 0.9255
# Epoch 125/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0786 - accuracy: 0.9613 - val_loss: 0.2070 - val_accuracy: 0.9250
# Epoch 126/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0762 - accuracy: 0.9613 - val_loss: 0.2005 - val_accuracy: 0.9310
# Epoch 127/500
# 10/10 [==============================] - 7s 745ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0765 - accuracy: 0.9604 - val_loss: 0.1823 - val_accuracy: 0.9341
# Epoch 128/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0632 - accuracy: 0.9678 - val_loss: 0.2005 - val_accuracy: 0.9271
# Epoch 129/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0797 - accuracy: 0.9594 - val_loss: 0.2004 - val_accuracy: 0.9277
# Epoch 130/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0801 - accuracy: 0.9609 - val_loss: 0.1781 - val_accuracy: 0.9282
# Epoch 131/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0694 - accuracy: 0.9640 - val_loss: 0.2129 - val_accuracy: 0.9216
# Epoch 132/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0806 - accuracy: 0.9616 - val_loss: 0.1636 - val_accuracy: 0.9362
# Epoch 133/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0768 - accuracy: 0.9607 - val_loss: 0.1879 - val_accuracy: 0.9312
# Epoch 134/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0690 - accuracy: 0.9647 - val_loss: 0.2370 - val_accuracy: 0.9178
# Epoch 135/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0698 - accuracy: 0.9636 - val_loss: 0.1924 - val_accuracy: 0.9292
# Epoch 136/500
# 10/10 [==============================] - 7s 723ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0750 - accuracy: 0.9616 - val_loss: 0.1876 - val_accuracy: 0.9297
# Epoch 137/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0628 - accuracy: 0.9683 - val_loss: 0.1710 - val_accuracy: 0.9353
# Epoch 138/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0680 - accuracy: 0.9652 - val_loss: 0.2006 - val_accuracy: 0.9290
# Epoch 139/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0637 - accuracy: 0.9660 - val_loss: 0.1759 - val_accuracy: 0.9321
# Epoch 140/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0665 - accuracy: 0.9666 - val_loss: 0.2548 - val_accuracy: 0.9210
# Epoch 141/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0721 - accuracy: 0.9628 - val_loss: 0.2317 - val_accuracy: 0.9143
# Epoch 142/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0588 - accuracy: 0.9681 - val_loss: 0.2156 - val_accuracy: 0.9257
# Epoch 143/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0894 - accuracy: 0.9558 - val_loss: 0.1805 - val_accuracy: 0.9287
# Epoch 144/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0652 - accuracy: 0.9670 - val_loss: 0.1967 - val_accuracy: 0.9266
# Epoch 145/500
# 10/10 [==============================] - 7s 736ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0685 - accuracy: 0.9642 - val_loss: 0.2156 - val_accuracy: 0.9188
# Epoch 146/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0639 - accuracy: 0.9676 - val_loss: 0.1805 - val_accuracy: 0.9281
# Epoch 147/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0670 - accuracy: 0.9651 - val_loss: 0.1833 - val_accuracy: 0.9330
# Epoch 148/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0709 - accuracy: 0.9639 - val_loss: 0.1636 - val_accuracy: 0.9377
# Epoch 149/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0684 - accuracy: 0.9643 - val_loss: 0.1917 - val_accuracy: 0.9297
# Epoch 150/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0604 - accuracy: 0.9690 - val_loss: 0.1755 - val_accuracy: 0.9343
# Epoch 151/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0732 - accuracy: 0.9610 - val_loss: 0.2005 - val_accuracy: 0.9337
# Epoch 152/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0517 - accuracy: 0.9725 - val_loss: 0.1712 - val_accuracy: 0.9348
# Epoch 153/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0793 - accuracy: 0.9591 - val_loss: 0.2605 - val_accuracy: 0.9211
# Epoch 154/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0648 - accuracy: 0.9647 - val_loss: 0.2128 - val_accuracy: 0.9257
# Epoch 155/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0622 - accuracy: 0.9672 - val_loss: 0.1823 - val_accuracy: 0.9307
# Epoch 156/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0654 - accuracy: 0.9653 - val_loss: 0.2101 - val_accuracy: 0.9259
# Epoch 157/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0619 - accuracy: 0.9681 - val_loss: 0.2277 - val_accuracy: 0.9251
# Epoch 158/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0672 - accuracy: 0.9647 - val_loss: 0.2097 - val_accuracy: 0.9171
# Epoch 159/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0617 - accuracy: 0.9662 - val_loss: 0.1829 - val_accuracy: 0.9295
# Epoch 160/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0582 - accuracy: 0.9686 - val_loss: 0.1835 - val_accuracy: 0.9322
# Epoch 161/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0630 - accuracy: 0.9676 - val_loss: 0.1868 - val_accuracy: 0.9287
# Epoch 162/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0645 - accuracy: 0.9644 - val_loss: 0.1636 - val_accuracy: 0.9329
# Epoch 163/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0548 - accuracy: 0.9705 - val_loss: 0.1866 - val_accuracy: 0.9291
# Epoch 164/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0709 - accuracy: 0.9628 - val_loss: 0.1747 - val_accuracy: 0.9378
# Epoch 165/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0625 - accuracy: 0.9665 - val_loss: 0.1704 - val_accuracy: 0.9346
# Epoch 166/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0632 - accuracy: 0.9675 - val_loss: 0.2045 - val_accuracy: 0.9324
# Epoch 167/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0549 - accuracy: 0.9709 - val_loss: 0.1487 - val_accuracy: 0.9362
# Epoch 168/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0778 - accuracy: 0.9595 - val_loss: 0.1965 - val_accuracy: 0.9281
# Epoch 169/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0830 - accuracy: 0.9581 - val_loss: 0.1968 - val_accuracy: 0.9338
# Epoch 170/500
# 10/10 [==============================] - 7s 717ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0655 - accuracy: 0.9651 - val_loss: 0.1875 - val_accuracy: 0.9360
# Epoch 171/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0560 - accuracy: 0.9705 - val_loss: 0.1676 - val_accuracy: 0.9363
# Epoch 172/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0528 - accuracy: 0.9692 - val_loss: 0.2155 - val_accuracy: 0.9313
# Epoch 173/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0667 - accuracy: 0.9636 - val_loss: 0.2078 - val_accuracy: 0.9337
# Epoch 174/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0474 - accuracy: 0.9739 - val_loss: 0.1609 - val_accuracy: 0.9411
# Epoch 175/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0606 - accuracy: 0.9663 - val_loss: 0.1714 - val_accuracy: 0.9384
# Epoch 176/500
# 10/10 [==============================] - 7s 723ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0484 - accuracy: 0.9757 - val_loss: 0.2042 - val_accuracy: 0.9320
# Epoch 177/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0622 - accuracy: 0.9662 - val_loss: 0.1984 - val_accuracy: 0.9331
# Epoch 178/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0601 - accuracy: 0.9686 - val_loss: 0.2213 - val_accuracy: 0.9211
# Epoch 179/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0532 - accuracy: 0.9704 - val_loss: 0.2484 - val_accuracy: 0.9214
# Epoch 180/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0609 - accuracy: 0.9678 - val_loss: 0.1987 - val_accuracy: 0.9253
# Epoch 181/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0679 - accuracy: 0.9636 - val_loss: 0.2112 - val_accuracy: 0.9321
# Epoch 182/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0463 - accuracy: 0.9738 - val_loss: 0.2313 - val_accuracy: 0.9314
# Epoch 183/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0534 - accuracy: 0.9723 - val_loss: 0.1926 - val_accuracy: 0.9363
# Epoch 184/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0646 - accuracy: 0.9647 - val_loss: 0.1695 - val_accuracy: 0.9375
# Epoch 185/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0493 - accuracy: 0.9734 - val_loss: 0.2065 - val_accuracy: 0.9315
# Epoch 186/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0622 - accuracy: 0.9648 - val_loss: 0.2743 - val_accuracy: 0.9196
# Epoch 187/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0486 - accuracy: 0.9737 - val_loss: 0.1942 - val_accuracy: 0.9365
# Epoch 188/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0616 - accuracy: 0.9640 - val_loss: 0.2179 - val_accuracy: 0.9268
# Epoch 189/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0678 - accuracy: 0.9657 - val_loss: 0.2230 - val_accuracy: 0.9246
# Epoch 190/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0696 - accuracy: 0.9639 - val_loss: 0.2070 - val_accuracy: 0.9265
# Epoch 191/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0455 - accuracy: 0.9759 - val_loss: 0.1636 - val_accuracy: 0.9393
# Epoch 192/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0756 - accuracy: 0.9598 - val_loss: 0.1562 - val_accuracy: 0.9430
# Epoch 193/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0572 - accuracy: 0.9696 - val_loss: 0.1611 - val_accuracy: 0.9356
# Epoch 194/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0581 - accuracy: 0.9681 - val_loss: 0.2352 - val_accuracy: 0.9273
# Epoch 195/500
# 10/10 [==============================] - 7s 737ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0549 - accuracy: 0.9683 - val_loss: 0.1805 - val_accuracy: 0.9338
# Epoch 196/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0463 - accuracy: 0.9745 - val_loss: 0.1775 - val_accuracy: 0.9330
# Epoch 197/500
# 10/10 [==============================] - 7s 737ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0560 - accuracy: 0.9681 - val_loss: 0.2209 - val_accuracy: 0.9283
# Epoch 198/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0629 - accuracy: 0.9684 - val_loss: 0.1592 - val_accuracy: 0.9398
# Epoch 199/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0504 - accuracy: 0.9717 - val_loss: 0.2330 - val_accuracy: 0.9213
# Epoch 200/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0662 - accuracy: 0.9642 - val_loss: 0.2002 - val_accuracy: 0.9328
# Epoch 201/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0617 - accuracy: 0.9660 - val_loss: 0.1848 - val_accuracy: 0.9332
# Epoch 202/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0466 - accuracy: 0.9731 - val_loss: 0.1906 - val_accuracy: 0.9351
# Epoch 203/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0520 - accuracy: 0.9708 - val_loss: 0.3104 - val_accuracy: 0.9175
# Epoch 204/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0478 - accuracy: 0.9723 - val_loss: 0.2164 - val_accuracy: 0.9260
# Epoch 205/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0543 - accuracy: 0.9687 - val_loss: 0.2307 - val_accuracy: 0.9278
# Epoch 206/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0408 - accuracy: 0.9764 - val_loss: 0.1770 - val_accuracy: 0.9330
# Epoch 207/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0554 - accuracy: 0.9696 - val_loss: 0.1878 - val_accuracy: 0.9309
# Epoch 208/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0576 - accuracy: 0.9670 - val_loss: 0.1737 - val_accuracy: 0.9378
# Epoch 209/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0519 - accuracy: 0.9712 - val_loss: 0.2486 - val_accuracy: 0.9222
# Epoch 210/500
# 10/10 [==============================] - 7s 723ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0506 - accuracy: 0.9706 - val_loss: 0.2236 - val_accuracy: 0.9233
# Epoch 211/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0544 - accuracy: 0.9691 - val_loss: 0.2091 - val_accuracy: 0.9336
# Epoch 212/500
# 10/10 [==============================] - 7s 726ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0447 - accuracy: 0.9732 - val_loss: 0.2107 - val_accuracy: 0.9285
# Epoch 213/500
# 10/10 [==============================] - 7s 747ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0485 - accuracy: 0.9722 - val_loss: 0.2731 - val_accuracy: 0.9271
# Epoch 214/500
# 10/10 [==============================] - 7s 727ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0457 - accuracy: 0.9734 - val_loss: 0.2285 - val_accuracy: 0.9281
# Epoch 215/500
# 10/10 [==============================] - 7s 747ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0460 - accuracy: 0.9729 - val_loss: 0.2051 - val_accuracy: 0.9347
# Epoch 216/500
# 10/10 [==============================] - 7s 726ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0433 - accuracy: 0.9737 - val_loss: 0.2174 - val_accuracy: 0.9332
# Epoch 217/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0403 - accuracy: 0.9749 - val_loss: 0.2166 - val_accuracy: 0.9335
# Epoch 218/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0465 - accuracy: 0.9730 - val_loss: 0.1929 - val_accuracy: 0.9376
# Epoch 219/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0494 - accuracy: 0.9706 - val_loss: 0.2211 - val_accuracy: 0.9400
# Epoch 220/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0428 - accuracy: 0.9748 - val_loss: 0.2488 - val_accuracy: 0.9251
# Epoch 221/500
# 10/10 [==============================] - 7s 747ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0572 - accuracy: 0.9666 - val_loss: 0.1956 - val_accuracy: 0.9377
# Epoch 222/500
# 10/10 [==============================] - 7s 728ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0422 - accuracy: 0.9763 - val_loss: 0.2091 - val_accuracy: 0.9320
# Epoch 223/500
# 10/10 [==============================] - 7s 745ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0562 - accuracy: 0.9673 - val_loss: 0.1737 - val_accuracy: 0.9434
# Epoch 224/500
# 10/10 [==============================] - 7s 726ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0402 - accuracy: 0.9780 - val_loss: 0.2265 - val_accuracy: 0.9300
# Epoch 225/500
# 10/10 [==============================] - 7s 744ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0448 - accuracy: 0.9741 - val_loss: 0.2837 - val_accuracy: 0.9231
# Epoch 226/500
# 10/10 [==============================] - 7s 728ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0509 - accuracy: 0.9706 - val_loss: 0.2082 - val_accuracy: 0.9310
# Epoch 227/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0448 - accuracy: 0.9736 - val_loss: 0.2127 - val_accuracy: 0.9335
# Epoch 228/500
# 10/10 [==============================] - 7s 726ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0459 - accuracy: 0.9724 - val_loss: 0.2349 - val_accuracy: 0.9357
# Epoch 229/500
# 10/10 [==============================] - 7s 744ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0517 - accuracy: 0.9691 - val_loss: 0.2460 - val_accuracy: 0.9356
# Epoch 230/500
# 10/10 [==============================] - 7s 725ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0381 - accuracy: 0.9780 - val_loss: 0.2268 - val_accuracy: 0.9302
# Epoch 231/500
# 10/10 [==============================] - 7s 745ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0428 - accuracy: 0.9751 - val_loss: 0.2177 - val_accuracy: 0.9301
# Epoch 232/500
# 10/10 [==============================] - 7s 728ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0493 - accuracy: 0.9705 - val_loss: 0.1962 - val_accuracy: 0.9370
# Epoch 233/500
# 10/10 [==============================] - 7s 745ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0511 - accuracy: 0.9712 - val_loss: 0.1815 - val_accuracy: 0.9359
# Epoch 234/500
# 10/10 [==============================] - 7s 729ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0442 - accuracy: 0.9733 - val_loss: 0.1872 - val_accuracy: 0.9335
# Epoch 235/500
# 10/10 [==============================] - 7s 747ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0501 - accuracy: 0.9705 - val_loss: 0.1854 - val_accuracy: 0.9353
# Epoch 236/500
# 10/10 [==============================] - 7s 724ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0351 - accuracy: 0.9780 - val_loss: 0.1954 - val_accuracy: 0.9337
# Epoch 237/500
# 10/10 [==============================] - 7s 744ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0398 - accuracy: 0.9763 - val_loss: 0.2223 - val_accuracy: 0.9280
# Epoch 238/500
# 10/10 [==============================] - 7s 727ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0601 - accuracy: 0.9672 - val_loss: 0.2370 - val_accuracy: 0.9279
# Epoch 239/500
# 10/10 [==============================] - 7s 747ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0805 - accuracy: 0.9578 - val_loss: 0.2057 - val_accuracy: 0.9197
# Epoch 240/500
# 10/10 [==============================] - 7s 723ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0526 - accuracy: 0.9711 - val_loss: 0.2224 - val_accuracy: 0.9265
# Epoch 241/500
# 10/10 [==============================] - 7s 749ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0428 - accuracy: 0.9756 - val_loss: 0.1559 - val_accuracy: 0.9374
# Epoch 242/500
# 10/10 [==============================] - 7s 727ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0573 - accuracy: 0.9687 - val_loss: 0.1707 - val_accuracy: 0.9379
# Epoch 243/500
# 10/10 [==============================] - 7s 746ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0422 - accuracy: 0.9751 - val_loss: 0.2076 - val_accuracy: 0.9285
# Epoch 244/500
# 10/10 [==============================] - 7s 726ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0481 - accuracy: 0.9715 - val_loss: 0.1735 - val_accuracy: 0.9353
# Epoch 245/500
# 10/10 [==============================] - 7s 746ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0397 - accuracy: 0.9763 - val_loss: 0.1845 - val_accuracy: 0.9375
# Epoch 246/500
# 10/10 [==============================] - 7s 729ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0457 - accuracy: 0.9714 - val_loss: 0.2218 - val_accuracy: 0.9334
# Epoch 247/500
# 10/10 [==============================] - 7s 746ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0495 - accuracy: 0.9706 - val_loss: 0.2096 - val_accuracy: 0.9318
# Epoch 248/500
# 10/10 [==============================] - 7s 726ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0347 - accuracy: 0.9778 - val_loss: 0.1904 - val_accuracy: 0.9329
# Epoch 249/500
# 10/10 [==============================] - 7s 748ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0351 - accuracy: 0.9796 - val_loss: 0.1964 - val_accuracy: 0.9391
# Epoch 250/500
# 10/10 [==============================] - 7s 725ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0517 - accuracy: 0.9682 - val_loss: 0.2318 - val_accuracy: 0.9303
# Epoch 251/500
# 10/10 [==============================] - 7s 747ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0457 - accuracy: 0.9730 - val_loss: 0.2051 - val_accuracy: 0.9373
# Epoch 252/500
# 10/10 [==============================] - 7s 728ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0380 - accuracy: 0.9759 - val_loss: 0.2663 - val_accuracy: 0.9273
# Epoch 253/500
# 10/10 [==============================] - 7s 745ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0557 - accuracy: 0.9668 - val_loss: 0.1732 - val_accuracy: 0.9444
# Epoch 254/500
# 10/10 [==============================] - 7s 727ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0316 - accuracy: 0.9809 - val_loss: 0.2547 - val_accuracy: 0.9278
# Epoch 255/500
# 10/10 [==============================] - 7s 744ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0500 - accuracy: 0.9712 - val_loss: 0.2095 - val_accuracy: 0.9331
# Epoch 256/500
# 10/10 [==============================] - 7s 729ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0437 - accuracy: 0.9741 - val_loss: 0.1949 - val_accuracy: 0.9366
# Epoch 257/500
# 10/10 [==============================] - 7s 746ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0453 - accuracy: 0.9727 - val_loss: 0.2508 - val_accuracy: 0.9335
# Epoch 258/500
# 10/10 [==============================] - 7s 725ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0378 - accuracy: 0.9765 - val_loss: 0.2202 - val_accuracy: 0.9337
# Epoch 259/500
# 10/10 [==============================] - 7s 746ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0374 - accuracy: 0.9767 - val_loss: 0.2302 - val_accuracy: 0.9278
# Epoch 260/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0428 - accuracy: 0.9739 - val_loss: 0.2208 - val_accuracy: 0.9309
# Epoch 261/500
# 10/10 [==============================] - 7s 744ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0338 - accuracy: 0.9790 - val_loss: 0.2066 - val_accuracy: 0.9366
# Epoch 262/500
# 10/10 [==============================] - 7s 725ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0420 - accuracy: 0.9725 - val_loss: 0.2272 - val_accuracy: 0.9333
# Epoch 263/500
# 10/10 [==============================] - 7s 746ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0367 - accuracy: 0.9770 - val_loss: 0.2403 - val_accuracy: 0.9321
# Epoch 264/500
# 10/10 [==============================] - 7s 728ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0390 - accuracy: 0.9752 - val_loss: 0.2733 - val_accuracy: 0.9279
# Epoch 265/500
# 10/10 [==============================] - 7s 744ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0416 - accuracy: 0.9746 - val_loss: 0.1830 - val_accuracy: 0.9362
# Epoch 266/500
# 10/10 [==============================] - 7s 727ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0391 - accuracy: 0.9755 - val_loss: 0.2300 - val_accuracy: 0.9330
# Epoch 267/500
# 10/10 [==============================] - 7s 744ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0416 - accuracy: 0.9740 - val_loss: 0.2180 - val_accuracy: 0.9392
# Epoch 268/500
# ...
# Epoch 411/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0317 - accuracy: 0.9769 - val_loss: 0.2222 - val_accuracy: 0.9396
# Epoch 412/500
# 10/10 [==============================] - 7s 724ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0257 - accuracy: 0.9821 - val_loss: 0.2378 - val_accuracy: 0.9322
# Epoch 413/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0289 - accuracy: 0.9790 - val_loss: 0.2492 - val_accuracy: 0.9308
# Epoch 414/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0309 - accuracy: 0.9788 - val_loss: 0.2600 - val_accuracy: 0.9372
# Epoch 415/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0359 - accuracy: 0.9758 - val_loss: 0.1790 - val_accuracy: 0.9412
# Epoch 416/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0328 - accuracy: 0.9799 - val_loss: 0.2192 - val_accuracy: 0.9359
# Epoch 417/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0292 - accuracy: 0.9801 - val_loss: 0.2573 - val_accuracy: 0.9332
# Epoch 418/500
# 10/10 [==============================] - 7s 723ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0361 - accuracy: 0.9757 - val_loss: 0.2594 - val_accuracy: 0.9317
# Epoch 419/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0312 - accuracy: 0.9787 - val_loss: 0.2206 - val_accuracy: 0.9330
# Epoch 420/500
# 10/10 [==============================] - 7s 718ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0313 - accuracy: 0.9787 - val_loss: 0.2334 - val_accuracy: 0.9357
# Epoch 421/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0317 - accuracy: 0.9781 - val_loss: 0.2300 - val_accuracy: 0.9332
# Epoch 422/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0353 - accuracy: 0.9765 - val_loss: 0.2451 - val_accuracy: 0.9355
# Epoch 423/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0352 - accuracy: 0.9760 - val_loss: 0.2190 - val_accuracy: 0.9423
# Epoch 424/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0314 - accuracy: 0.9788 - val_loss: 0.2664 - val_accuracy: 0.9281
# Epoch 425/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0306 - accuracy: 0.9797 - val_loss: 0.1971 - val_accuracy: 0.9389
# Epoch 426/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0327 - accuracy: 0.9772 - val_loss: 0.2559 - val_accuracy: 0.9346
# Epoch 427/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0298 - accuracy: 0.9798 - val_loss: 0.2115 - val_accuracy: 0.9416
# Epoch 428/500
# 10/10 [==============================] - 7s 723ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0341 - accuracy: 0.9760 - val_loss: 0.2418 - val_accuracy: 0.9290
# Epoch 429/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0370 - accuracy: 0.9751 - val_loss: 0.2006 - val_accuracy: 0.9377
# Epoch 430/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0264 - accuracy: 0.9820 - val_loss: 0.2215 - val_accuracy: 0.9338
# Epoch 431/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0307 - accuracy: 0.9782 - val_loss: 0.2494 - val_accuracy: 0.9341
# Epoch 432/500
# 10/10 [==============================] - 7s 723ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0281 - accuracy: 0.9798 - val_loss: 0.2350 - val_accuracy: 0.9328
# Epoch 433/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0258 - accuracy: 0.9809 - val_loss: 0.2350 - val_accuracy: 0.9370
# Epoch 434/500
# 10/10 [==============================] - 7s 719ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0348 - accuracy: 0.9768 - val_loss: 0.2170 - val_accuracy: 0.9403
# Epoch 435/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0316 - accuracy: 0.9774 - val_loss: 0.2516 - val_accuracy: 0.9340
# Epoch 436/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0308 - accuracy: 0.9803 - val_loss: 0.2237 - val_accuracy: 0.9363
# Epoch 437/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0322 - accuracy: 0.9772 - val_loss: 0.1833 - val_accuracy: 0.9432
# Epoch 438/500
# 10/10 [==============================] - 7s 724ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0330 - accuracy: 0.9787 - val_loss: 0.2537 - val_accuracy: 0.9307
# Epoch 439/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0274 - accuracy: 0.9815 - val_loss: 0.2306 - val_accuracy: 0.9334
# Epoch 440/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0384 - accuracy: 0.9748 - val_loss: 0.2659 - val_accuracy: 0.9323
# Epoch 441/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0312 - accuracy: 0.9790 - val_loss: 0.2551 - val_accuracy: 0.9323
# Epoch 442/500
# 10/10 [==============================] - 7s 723ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0312 - accuracy: 0.9773 - val_loss: 0.2338 - val_accuracy: 0.9380
# Epoch 443/500
# 10/10 [==============================] - 7s 740ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0312 - accuracy: 0.9779 - val_loss: 0.2778 - val_accuracy: 0.9328
# Epoch 444/500
# 10/10 [==============================] - 7s 725ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0262 - accuracy: 0.9806 - val_loss: 0.2456 - val_accuracy: 0.9379
# Epoch 445/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0239 - accuracy: 0.9820 - val_loss: 0.2294 - val_accuracy: 0.9358
# Epoch 446/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0304 - accuracy: 0.9779 - val_loss: 0.2491 - val_accuracy: 0.9354
# Epoch 447/500
# 10/10 [==============================] - 7s 745ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0288 - accuracy: 0.9788 - val_loss: 0.2769 - val_accuracy: 0.9342
# Epoch 448/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0254 - accuracy: 0.9806 - val_loss: 0.2706 - val_accuracy: 0.9322
# Epoch 449/500
# 10/10 [==============================] - 7s 744ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0239 - accuracy: 0.9820 - val_loss: 0.1946 - val_accuracy: 0.9436
# Epoch 450/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0308 - accuracy: 0.9778 - val_loss: 0.2403 - val_accuracy: 0.9380
# Epoch 451/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0317 - accuracy: 0.9765 - val_loss: 0.2771 - val_accuracy: 0.9354
# Epoch 452/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0252 - accuracy: 0.9830 - val_loss: 0.2170 - val_accuracy: 0.9369
# Epoch 453/500
# 10/10 [==============================] - 7s 744ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0287 - accuracy: 0.9788 - val_loss: 0.2239 - val_accuracy: 0.9410
# Epoch 454/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0273 - accuracy: 0.9798 - val_loss: 0.1849 - val_accuracy: 0.9411
# Epoch 455/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0318 - accuracy: 0.9771 - val_loss: 0.2466 - val_accuracy: 0.9353
# Epoch 456/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0250 - accuracy: 0.9820 - val_loss: 0.2703 - val_accuracy: 0.9334
# Epoch 457/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0303 - accuracy: 0.9777 - val_loss: 0.3093 - val_accuracy: 0.9234
# Epoch 458/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0252 - accuracy: 0.9811 - val_loss: 0.2361 - val_accuracy: 0.9353
# Epoch 459/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0248 - accuracy: 0.9810 - val_loss: 0.1965 - val_accuracy: 0.9424
# Epoch 460/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0337 - accuracy: 0.9766 - val_loss: 0.2720 - val_accuracy: 0.9312
# Epoch 461/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0367 - accuracy: 0.9745 - val_loss: 0.2333 - val_accuracy: 0.9354
# Epoch 462/500
# 10/10 [==============================] - 7s 725ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0466 - accuracy: 0.9746 - val_loss: 0.1582 - val_accuracy: 0.9384
# Epoch 463/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0489 - accuracy: 0.9714 - val_loss: 0.2141 - val_accuracy: 0.9312
# Epoch 464/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0503 - accuracy: 0.9706 - val_loss: 0.2570 - val_accuracy: 0.9319
# Epoch 465/500
# 10/10 [==============================] - 7s 737ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0432 - accuracy: 0.9744 - val_loss: 0.1699 - val_accuracy: 0.9418
# Epoch 466/500
# 10/10 [==============================] - 7s 724ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0389 - accuracy: 0.9746 - val_loss: 0.2356 - val_accuracy: 0.9353
# Epoch 467/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0369 - accuracy: 0.9754 - val_loss: 0.2009 - val_accuracy: 0.9367
# Epoch 468/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0305 - accuracy: 0.9796 - val_loss: 0.2426 - val_accuracy: 0.9349
# Epoch 469/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0367 - accuracy: 0.9740 - val_loss: 0.2526 - val_accuracy: 0.9324
# Epoch 470/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0256 - accuracy: 0.9835 - val_loss: 0.2327 - val_accuracy: 0.9362
# Epoch 471/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0299 - accuracy: 0.9794 - val_loss: 0.2229 - val_accuracy: 0.9350
# Epoch 472/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0295 - accuracy: 0.9784 - val_loss: 0.2794 - val_accuracy: 0.9371
# Epoch 473/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0271 - accuracy: 0.9809 - val_loss: 0.2082 - val_accuracy: 0.9403
# Epoch 474/500
# 10/10 [==============================] - 7s 724ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0336 - accuracy: 0.9773 - val_loss: 0.2299 - val_accuracy: 0.9327
# Epoch 475/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0288 - accuracy: 0.9780 - val_loss: 0.2740 - val_accuracy: 0.9325
# Epoch 476/500
# 10/10 [==============================] - 7s 723ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0254 - accuracy: 0.9822 - val_loss: 0.2537 - val_accuracy: 0.9342
# Epoch 477/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0290 - accuracy: 0.9789 - val_loss: 0.2218 - val_accuracy: 0.9417
# Epoch 478/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0256 - accuracy: 0.9807 - val_loss: 0.2590 - val_accuracy: 0.9370
# Epoch 479/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0281 - accuracy: 0.9792 - val_loss: 0.1852 - val_accuracy: 0.9445
# Epoch 480/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0280 - accuracy: 0.9803 - val_loss: 0.2307 - val_accuracy: 0.9377
# Epoch 481/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0308 - accuracy: 0.9775 - val_loss: 0.2441 - val_accuracy: 0.9398
# Epoch 482/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0243 - accuracy: 0.9814 - val_loss: 0.2551 - val_accuracy: 0.9347
# Epoch 483/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0284 - accuracy: 0.9789 - val_loss: 0.2050 - val_accuracy: 0.9390
# Epoch 484/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0252 - accuracy: 0.9814 - val_loss: 0.2261 - val_accuracy: 0.9431
# Epoch 485/500
# 10/10 [==============================] - 7s 738ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0276 - accuracy: 0.9795 - val_loss: 0.3022 - val_accuracy: 0.9317
# Epoch 486/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0240 - accuracy: 0.9812 - val_loss: 0.2452 - val_accuracy: 0.9335
# Epoch 487/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0272 - accuracy: 0.9796 - val_loss: 0.3003 - val_accuracy: 0.9292
# Epoch 488/500
# 10/10 [==============================] - 7s 722ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0262 - accuracy: 0.9804 - val_loss: 0.2570 - val_accuracy: 0.9367
# Epoch 489/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0258 - accuracy: 0.9813 - val_loss: 0.2293 - val_accuracy: 0.9482
# Epoch 490/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0294 - accuracy: 0.9781 - val_loss: 0.2065 - val_accuracy: 0.9385
# Epoch 491/500
# 10/10 [==============================] - 7s 743ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0266 - accuracy: 0.9804 - val_loss: 0.2664 - val_accuracy: 0.9357
# Epoch 492/500
# 10/10 [==============================] - 7s 723ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0279 - accuracy: 0.9800 - val_loss: 0.2861 - val_accuracy: 0.9300
# Epoch 493/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0266 - accuracy: 0.9808 - val_loss: 0.2445 - val_accuracy: 0.9409
# Epoch 494/500
# 10/10 [==============================] - 7s 726ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0306 - accuracy: 0.9780 - val_loss: 0.2011 - val_accuracy: 0.9462
# Epoch 495/500
# 10/10 [==============================] - 7s 739ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0225 - accuracy: 0.9834 - val_loss: 0.2499 - val_accuracy: 0.9390
# Epoch 496/500
# 10/10 [==============================] - 7s 723ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0304 - accuracy: 0.9764 - val_loss: 0.2408 - val_accuracy: 0.9379
# Epoch 497/500
# 10/10 [==============================] - 7s 741ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0225 - accuracy: 0.9820 - val_loss: 0.2600 - val_accuracy: 0.9387
# Epoch 498/500
# 10/10 [==============================] - 7s 721ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0279 - accuracy: 0.9784 - val_loss: 0.2403 - val_accuracy: 0.9423
# Epoch 499/500
# 10/10 [==============================] - 7s 742ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0302 - accuracy: 0.9774 - val_loss: 0.2094 - val_accuracy: 0.9412
# Epoch 500/500
# 10/10 [==============================] - 7s 720ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.0238 - accuracy: 0.9825 - val_loss: 0.2478 - val_accuracy: 0.9383

# %%
#保存模型
model_checkpoint = ModelCheckpoint('/content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5', monitor='loss',verbose=1, save_best_only=True)
model.fit_generator(myGene,steps_per_epoch=10,epochs=100,callbacks=[model_checkpoint]) #epoch循环次数
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:1228: UserWarning: `model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`model.fit_generator` is deprecated and '
# Epoch 1/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.6441 - accuracy: 0.6477
# Epoch 00001: loss improved from inf to 0.64408, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 30s 3s/step - batch: 4.5000 - size: 2.0000 - loss: 0.6441 - accuracy: 0.6477
# Epoch 2/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.5286 - accuracy: 0.7003
# Epoch 00002: loss improved from 0.64408 to 0.54142, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 24s 3s/step - batch: 4.5000 - size: 1.9000 - loss: 0.5298 - accuracy: 0.7003
# Epoch 3/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.4206 - accuracy: 0.8221
# Epoch 00003: loss improved from 0.54142 to 0.42062, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 21s 2s/step - batch: 4.5000 - size: 2.0000 - loss: 0.4206 - accuracy: 0.8221
# Epoch 4/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.5079 - accuracy: 0.7451
# Epoch 00004: loss did not improve from 0.42062
# 10/10 [==============================] - 5s 519ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.5059 - accuracy: 0.7451
# Epoch 5/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.5159 - accuracy: 0.7641
# Epoch 00005: loss did not improve from 0.42062
# 10/10 [==============================] - 5s 538ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.5159 - accuracy: 0.7641
# Epoch 6/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.5075 - accuracy: 0.7458
# Epoch 00006: loss did not improve from 0.42062
# 10/10 [==============================] - 5s 519ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.5072 - accuracy: 0.7458
# Epoch 7/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.3904 - accuracy: 0.7999
# Epoch 00007: loss improved from 0.42062 to 0.39036, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 10s 1s/step - batch: 4.5000 - size: 2.0000 - loss: 0.3904 - accuracy: 0.7999
# Epoch 8/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.4228 - accuracy: 0.7968
# Epoch 00008: loss did not improve from 0.39036
# 10/10 [==============================] - 5s 517ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.4230 - accuracy: 0.7968
# Epoch 9/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.4815 - accuracy: 0.7941
# Epoch 00009: loss did not improve from 0.39036
# 10/10 [==============================] - 5s 539ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.4815 - accuracy: 0.7941
# Epoch 10/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.3611 - accuracy: 0.8404
# Epoch 00010: loss improved from 0.39036 to 0.37082, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 16s 2s/step - batch: 4.5000 - size: 1.9000 - loss: 0.3620 - accuracy: 0.8404
# Epoch 11/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.4327 - accuracy: 0.7949
# Epoch 00011: loss did not improve from 0.37082
# 10/10 [==============================] - 5s 536ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.4327 - accuracy: 0.7949
# Epoch 12/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.4370 - accuracy: 0.7828
# Epoch 00012: loss did not improve from 0.37082
# 10/10 [==============================] - 5s 516ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.4360 - accuracy: 0.7828
# Epoch 13/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.4232 - accuracy: 0.7793
# Epoch 00013: loss did not improve from 0.37082
# 10/10 [==============================] - 5s 538ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.4232 - accuracy: 0.7793
# Epoch 14/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.3322 - accuracy: 0.8129
# Epoch 00014: loss improved from 0.37082 to 0.34494, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 10s 1s/step - batch: 4.5000 - size: 1.9000 - loss: 0.3334 - accuracy: 0.8129
# Epoch 15/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.3496 - accuracy: 0.8419
# Epoch 00015: loss did not improve from 0.34494
# 10/10 [==============================] - 5s 534ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.3496 - accuracy: 0.8419
# Epoch 16/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.3884 - accuracy: 0.8140
# Epoch 00016: loss did not improve from 0.34494
# 10/10 [==============================] - 5s 520ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.3885 - accuracy: 0.8140
# Epoch 17/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.3528 - accuracy: 0.8184
# Epoch 00017: loss did not improve from 0.34494
# 10/10 [==============================] - 5s 537ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.3528 - accuracy: 0.8184
# Epoch 18/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.3774 - accuracy: 0.8301
# Epoch 00018: loss did not improve from 0.34494
# 10/10 [==============================] - 5s 515ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.3767 - accuracy: 0.8301
# Epoch 19/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.2641 - accuracy: 0.8750
# Epoch 00019: loss improved from 0.34494 to 0.26412, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 24s 3s/step - batch: 4.5000 - size: 2.0000 - loss: 0.2641 - accuracy: 0.8750
# Epoch 20/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.2905 - accuracy: 0.8615
# Epoch 00020: loss did not improve from 0.26412
# 10/10 [==============================] - 5s 511ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.2898 - accuracy: 0.8615
# Epoch 21/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.3230 - accuracy: 0.8411
# Epoch 00021: loss did not improve from 0.26412
# 10/10 [==============================] - 5s 535ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.3230 - accuracy: 0.8411
# Epoch 22/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.2869 - accuracy: 0.8508
# Epoch 00022: loss did not improve from 0.26412
# 10/10 [==============================] - 5s 517ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.2880 - accuracy: 0.8508
# Epoch 23/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.2927 - accuracy: 0.8414
# Epoch 00023: loss did not improve from 0.26412
# 10/10 [==============================] - 5s 539ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2927 - accuracy: 0.8414
# Epoch 24/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.2318 - accuracy: 0.8890
# Epoch 00024: loss improved from 0.26412 to 0.23513, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 30s 3s/step - batch: 4.5000 - size: 1.9000 - loss: 0.2321 - accuracy: 0.8890
# Epoch 25/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.2483 - accuracy: 0.8788
# Epoch 00025: loss did not improve from 0.23513
# 10/10 [==============================] - 5s 534ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2483 - accuracy: 0.8788
# Epoch 26/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.2402 - accuracy: 0.8823
# Epoch 00026: loss did not improve from 0.23513
# 10/10 [==============================] - 5s 520ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.2405 - accuracy: 0.8823
# Epoch 27/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.2524 - accuracy: 0.8821
# Epoch 00027: loss did not improve from 0.23513
# 10/10 [==============================] - 5s 538ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2524 - accuracy: 0.8821
# Epoch 28/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.2160 - accuracy: 0.8961
# Epoch 00028: loss improved from 0.23513 to 0.22668, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 28s 3s/step - batch: 4.5000 - size: 1.9000 - loss: 0.2170 - accuracy: 0.8961
# Epoch 29/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.2162 - accuracy: 0.9033
# Epoch 00029: loss improved from 0.22668 to 0.21615, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 25s 3s/step - batch: 4.5000 - size: 2.0000 - loss: 0.2162 - accuracy: 0.9033
# Epoch 30/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.2216 - accuracy: 0.8971
# Epoch 00030: loss did not improve from 0.21615
# 10/10 [==============================] - 5s 517ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.2219 - accuracy: 0.8971
# Epoch 31/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.2324 - accuracy: 0.8910
# Epoch 00031: loss did not improve from 0.21615
# 10/10 [==============================] - 5s 541ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2324 - accuracy: 0.8910
# Epoch 32/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.2345 - accuracy: 0.8842
# Epoch 00032: loss did not improve from 0.21615
# 10/10 [==============================] - 5s 520ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.2355 - accuracy: 0.8842
# Epoch 33/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.2305 - accuracy: 0.8969
# Epoch 00033: loss did not improve from 0.21615
# 10/10 [==============================] - 5s 538ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2305 - accuracy: 0.8969
# Epoch 34/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1976 - accuracy: 0.9088
# Epoch 00034: loss improved from 0.21615 to 0.20343, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 25s 3s/step - batch: 4.5000 - size: 1.9000 - loss: 0.1981 - accuracy: 0.9088
# Epoch 35/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.2217 - accuracy: 0.8972
# Epoch 00035: loss did not improve from 0.20343
# 10/10 [==============================] - 5s 534ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2217 - accuracy: 0.8972
# Epoch 36/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.2042 - accuracy: 0.9132
# Epoch 00036: loss improved from 0.20343 to 0.19325, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 19s 2s/step - batch: 4.5000 - size: 1.9000 - loss: 0.2032 - accuracy: 0.9132
# Epoch 37/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1997 - accuracy: 0.9137
# Epoch 00037: loss did not improve from 0.19325
# 10/10 [==============================] - 5s 537ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1997 - accuracy: 0.9137
# Epoch 38/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.2045 - accuracy: 0.9078
# Epoch 00038: loss did not improve from 0.19325
# 10/10 [==============================] - 5s 520ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.2045 - accuracy: 0.9078
# Epoch 39/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.2084 - accuracy: 0.9021
# Epoch 00039: loss did not improve from 0.19325
# 10/10 [==============================] - 5s 540ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2084 - accuracy: 0.9021
# Epoch 40/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1761 - accuracy: 0.9136
# Epoch 00040: loss improved from 0.19325 to 0.18350, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 10s 1s/step - batch: 4.5000 - size: 1.9000 - loss: 0.1767 - accuracy: 0.9136
# Epoch 41/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1922 - accuracy: 0.9218
# Epoch 00041: loss did not improve from 0.18350
# 10/10 [==============================] - 5s 534ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1922 - accuracy: 0.9218
# Epoch 42/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.2401 - accuracy: 0.8937
# Epoch 00042: loss did not improve from 0.18350
# 10/10 [==============================] - 5s 521ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.2392 - accuracy: 0.8937
# Epoch 43/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1627 - accuracy: 0.9232
# Epoch 00043: loss improved from 0.18350 to 0.16269, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 12s 1s/step - batch: 4.5000 - size: 2.0000 - loss: 0.1627 - accuracy: 0.9232
# Epoch 44/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1628 - accuracy: 0.9344
# Epoch 00044: loss improved from 0.16269 to 0.16251, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 25s 3s/step - batch: 4.5000 - size: 1.9000 - loss: 0.1628 - accuracy: 0.9344
# Epoch 45/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1719 - accuracy: 0.9232
# Epoch 00045: loss did not improve from 0.16251
# 10/10 [==============================] - 5s 535ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1719 - accuracy: 0.9232
# Epoch 46/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1956 - accuracy: 0.9178
# Epoch 00046: loss did not improve from 0.16251
# 10/10 [==============================] - 5s 521ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1948 - accuracy: 0.9178
# Epoch 47/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1687 - accuracy: 0.9210
# Epoch 00047: loss did not improve from 0.16251
# 10/10 [==============================] - 5s 541ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1687 - accuracy: 0.9210
# Epoch 48/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1345 - accuracy: 0.9414
# Epoch 00048: loss improved from 0.16251 to 0.13241, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 34s 4s/step - batch: 4.5000 - size: 1.9000 - loss: 0.1343 - accuracy: 0.9414
# Epoch 49/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1859 - accuracy: 0.9172
# Epoch 00049: loss did not improve from 0.13241
# 10/10 [==============================] - 5s 537ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1859 - accuracy: 0.9172
# Epoch 50/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1619 - accuracy: 0.9278
# Epoch 00050: loss did not improve from 0.13241
# 10/10 [==============================] - 5s 519ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1619 - accuracy: 0.9278
# Epoch 51/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1387 - accuracy: 0.9413
# Epoch 00051: loss did not improve from 0.13241
# 10/10 [==============================] - 5s 541ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1387 - accuracy: 0.9413
# Epoch 52/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1592 - accuracy: 0.9271
# Epoch 00052: loss did not improve from 0.13241
# 10/10 [==============================] - 5s 520ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1591 - accuracy: 0.9271
# Epoch 53/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1442 - accuracy: 0.9369
# Epoch 00053: loss did not improve from 0.13241
# 10/10 [==============================] - 5s 536ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1442 - accuracy: 0.9369
# Epoch 54/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1846 - accuracy: 0.9149
# Epoch 00054: loss did not improve from 0.13241
# 10/10 [==============================] - 5s 520ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1849 - accuracy: 0.9149
# Epoch 55/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1560 - accuracy: 0.9292
# Epoch 00055: loss did not improve from 0.13241
# 10/10 [==============================] - 5s 539ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1560 - accuracy: 0.9292
# Epoch 56/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1185 - accuracy: 0.9462
# Epoch 00056: loss improved from 0.13241 to 0.12077, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 23s 2s/step - batch: 4.5000 - size: 1.9000 - loss: 0.1187 - accuracy: 0.9462
# Epoch 57/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1628 - accuracy: 0.9262
# Epoch 00057: loss did not improve from 0.12077
# 10/10 [==============================] - 5s 536ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1628 - accuracy: 0.9262
# Epoch 58/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1190 - accuracy: 0.9448
# Epoch 00058: loss did not improve from 0.12077
# 10/10 [==============================] - 5s 514ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1195 - accuracy: 0.9448
# Epoch 59/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1486 - accuracy: 0.9303
# Epoch 00059: loss did not improve from 0.12077
# 10/10 [==============================] - 5s 541ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1486 - accuracy: 0.9303
# Epoch 60/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1921 - accuracy: 0.9211
# Epoch 00060: loss did not improve from 0.12077
# 10/10 [==============================] - 5s 517ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1903 - accuracy: 0.9211
# Epoch 61/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1904 - accuracy: 0.9137
# Epoch 00061: loss did not improve from 0.12077
# 10/10 [==============================] - 5s 538ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1904 - accuracy: 0.9137
# Epoch 62/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1837 - accuracy: 0.9158
# Epoch 00062: loss did not improve from 0.12077
# 10/10 [==============================] - 5s 516ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1838 - accuracy: 0.9158
# Epoch 63/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1160 - accuracy: 0.9500
# Epoch 00063: loss improved from 0.12077 to 0.11599, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 24s 3s/step - batch: 4.5000 - size: 2.0000 - loss: 0.1160 - accuracy: 0.9500
# Epoch 64/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1363 - accuracy: 0.9356
# Epoch 00064: loss did not improve from 0.11599
# 10/10 [==============================] - 5s 517ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1364 - accuracy: 0.9356
# Epoch 65/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1364 - accuracy: 0.9356
# Epoch 00065: loss did not improve from 0.11599
# 10/10 [==============================] - 5s 539ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1364 - accuracy: 0.9356
# Epoch 66/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1125 - accuracy: 0.9550
# Epoch 00066: loss improved from 0.11599 to 0.10517, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 12s 1s/step - batch: 4.5000 - size: 1.9000 - loss: 0.1118 - accuracy: 0.9550
# Epoch 67/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1457 - accuracy: 0.9347
# Epoch 00067: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 534ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1457 - accuracy: 0.9347
# Epoch 68/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1472 - accuracy: 0.9368
# Epoch 00068: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 518ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1463 - accuracy: 0.9368
# Epoch 69/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1505 - accuracy: 0.9309
# Epoch 00069: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 542ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1505 - accuracy: 0.9309
# Epoch 70/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1296 - accuracy: 0.9428
# Epoch 00070: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 517ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1290 - accuracy: 0.9428
# Epoch 71/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1237 - accuracy: 0.9421
# Epoch 00071: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 537ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1237 - accuracy: 0.9421
# Epoch 72/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1042 - accuracy: 0.9492
# Epoch 00072: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 517ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1046 - accuracy: 0.9492
# Epoch 73/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1202 - accuracy: 0.9451
# Epoch 00073: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 536ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1202 - accuracy: 0.9451
# Epoch 74/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1165 - accuracy: 0.9448
# Epoch 00074: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 517ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1165 - accuracy: 0.9448
# Epoch 75/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1119 - accuracy: 0.9485
# Epoch 00075: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 536ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1119 - accuracy: 0.9485
# Epoch 76/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1267 - accuracy: 0.9421
# Epoch 00076: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 514ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1262 - accuracy: 0.9421
# Epoch 77/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1275 - accuracy: 0.9406
# Epoch 00077: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 534ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1275 - accuracy: 0.9406
# Epoch 78/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1401 - accuracy: 0.9365
# Epoch 00078: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 515ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1399 - accuracy: 0.9365
# Epoch 79/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1391 - accuracy: 0.9354
# Epoch 00079: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 538ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1391 - accuracy: 0.9354
# Epoch 80/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1452 - accuracy: 0.9297
# Epoch 00080: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 516ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1457 - accuracy: 0.9297
# Epoch 81/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1309 - accuracy: 0.9405
# Epoch 00081: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 538ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1309 - accuracy: 0.9405
# Epoch 82/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1170 - accuracy: 0.9434
# Epoch 00082: loss did not improve from 0.10517
# 10/10 [==============================] - 5s 515ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1174 - accuracy: 0.9434
# Epoch 83/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1040 - accuracy: 0.9518
# Epoch 00083: loss improved from 0.10517 to 0.10396, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 26s 3s/step - batch: 4.5000 - size: 2.0000 - loss: 0.1040 - accuracy: 0.9518
# Epoch 84/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1014 - accuracy: 0.9530
# Epoch 00084: loss improved from 0.10396 to 0.10152, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 26s 3s/step - batch: 4.5000 - size: 1.9000 - loss: 0.1014 - accuracy: 0.9530
# Epoch 85/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.0817 - accuracy: 0.9615
# Epoch 00085: loss improved from 0.10152 to 0.08167, saving model to /content/drive/MyDrive/2105Dinghu/model/M0908_td_100epochs.hdf5
# 10/10 [==============================] - 21s 2s/step - batch: 4.5000 - size: 2.0000 - loss: 0.0817 - accuracy: 0.9615
# Epoch 86/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1229 - accuracy: 0.9423
# Epoch 00086: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 517ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1227 - accuracy: 0.9423
# Epoch 87/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.0960 - accuracy: 0.9531
# Epoch 00087: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 540ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0960 - accuracy: 0.9531
# Epoch 88/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1200 - accuracy: 0.9409
# Epoch 00088: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 524ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1199 - accuracy: 0.9409
# Epoch 89/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1106 - accuracy: 0.9471
# Epoch 00089: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 543ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1106 - accuracy: 0.9471
# Epoch 90/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1305 - accuracy: 0.9384
# Epoch 00090: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 516ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1309 - accuracy: 0.9384
# Epoch 91/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1227 - accuracy: 0.9442
# Epoch 00091: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 537ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1227 - accuracy: 0.9442
# Epoch 92/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1170 - accuracy: 0.9465
# Epoch 00092: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 519ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1173 - accuracy: 0.9465
# Epoch 93/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.1120 - accuracy: 0.9462
# Epoch 00093: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 535ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.1120 - accuracy: 0.9462
# Epoch 94/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1233 - accuracy: 0.9425
# Epoch 00094: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 522ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1238 - accuracy: 0.9425
# Epoch 95/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.0954 - accuracy: 0.9542
# Epoch 00095: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 536ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.0954 - accuracy: 0.9542
# Epoch 96/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.1651 - accuracy: 0.9275
# Epoch 00096: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 516ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.1643 - accuracy: 0.9275
# Epoch 97/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.3387 - accuracy: 0.8609
# Epoch 00097: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 536ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.3387 - accuracy: 0.8609
# Epoch 98/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.2408 - accuracy: 0.8741
# Epoch 00098: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 515ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.2414 - accuracy: 0.8741
# Epoch 99/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 2.0000 - loss: 0.2511 - accuracy: 0.8702
# Epoch 00099: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 536ms/step - batch: 4.5000 - size: 2.0000 - loss: 0.2511 - accuracy: 0.8702
# Epoch 100/100
# 10/10 [==============================] - ETA: 0s - batch: 4.5000 - size: 1.9000 - loss: 0.2821 - accuracy: 0.8598
# Epoch 00100: loss did not improve from 0.08167
# 10/10 [==============================] - 5s 517ms/step - batch: 4.5000 - size: 1.9000 - loss: 0.2816 - accuracy: 0.8598

# %%
import matplotlib.pyplot as plt

def testGenerator(test_path,num_image = 30,target_size = (IMG_SIZE,IMG_SIZE),flag_multi_class = False,as_gray = True):
    for i in range(num_image):
        img = io.imread('/content/data_0521/test/m_1.tif_0_672.tif')#os.path.join(test_path,"%d.tif"%i),as_gray = as_gray)
        
        img = img / 255
        img = np.expand_dims(img, axis = 0)
        #img = trans.resize(img,target_size)
        #img = np.reshape(img,img.shape+(1,)) if (not flag_multi_class) else img
        #img = np.reshape(img,(1,)+img.shape)
        yield img

#def labelVisualize(num_class,color_dict,img):
#    img = img[:,:,0] if len(img.shape) == 3 else img
#    img_out = np.zeros(img.shape + (3,))
#    for i in range(num_class):
#        img_out[img == i,:] = color_dict[i]
#    return img_out / 255

def saveResult(save_path,npyfile,flag_multi_class = False,num_class = 2):
    for i,item in enumerate(npyfile):
#        img = labelVisualize(num_class,COLOR_DICT,item) if flag_multi_class else item[:,:,0]
        io.imsave(os.path.join(save_path,"%d_predict.tif"%i),item)



testGene = testGenerator("/content/data_0521/test/")
results = model.predict_generator(testGene,1,verbose=1)
print(results.shape)
conv_t_1 = results[:,:,:,0]
print(conv_t_1.shape)
#print(results.shape)
#saveResult("/content/new_FCN_0422/data",results)
#timg = np.squeeze(results, axis = 3)
#print(timg.shape)
conv_t_1 = np.squeeze(conv_t_1, axis = 0)
print(conv_t_1.shape)
print(conv_t_1)
plt.imshow(conv_t_1 )
#plt.imsave('/content/drive/My Drive/new_FCN_0411/result/m_1.tif_0_672.tif',conv_t_1,cmap='gray')
# Out:
# 1/1 [==============================] - 0s 43ms/step
# (1, 224, 224, 3)
# (1, 224, 224)
# (224, 224)
# [[0.9499326  0.99549216 0.9978957  ... 0.97610724 0.9836714  0.9139656 ]
#  [0.9846599  0.99900335 0.99895877 ... 0.991127   0.98821497 0.95349324]
#  [0.9921744  0.9995446  0.9988524  ... 0.9953227  0.9839264  0.9574317 ]
#  ...
#  [0.9472941  0.9751984  0.96694267 ... 0.99887997 0.99436295 0.9378636 ]
#  [0.9524864  0.9849793  0.98936856 ... 0.9954581  0.9694266  0.9109372 ]
#  [0.83279705 0.9462267  0.9596163  ... 0.97142744 0.88150096 0.66444063]]

# %%
import numpy as np 
import os
#import glob
import skimage.io as io
import skimage.transform as trans
import matplotlib.pyplot as plt

def testGenerator(test_path,num_image = 72,target_size = (224,224),flag_multi_class = False,as_gray = True):
    for img_name in os.listdir(test_path):
        img = io.imread(os.path.join(test_path,"%s"%img_name))#,as_gray = as_gray)
        img = img / 255
        img = np.expand_dims(img, axis=0)
        #img = trans.resize(img,target_size)
        #img = np.reshape(img,img.shape+(1,)) if (not flag_multi_class) else img
        #img = np.reshape(img,(1,)+img.shape)
        #yield img
        
        results = model.predict(img)
        print(results.shape)
        saveResult("/content/drive/My Drive/new_FCN_0411/result_0610/b/",results,img_name)
        print(img_name)

#def labelVisualize(num_class,color_dict,img):
#    img = img[:,:,0] if len(img.shape) == 3 else img
#    img_out = np.zeros(img.shape + (3,))
#    for i in range(num_class):
#        img_out[img == i,:] = color_dict[i]
#    return img_out / 255

def saveResult(save_path,npyfile,img_name,flag_multi_class = False,num_class = 2):
    for i,item in enumerate(npyfile):
        #print(item)
#        img = labelVisualize(num_class,COLOR_DICT,item) if flag_multi_class else item[:,:,0]
        io.imsave(os.path.join(save_path,img_name),item)
        #plt.imsave('/content/drive/My Drive/FCN/plt_img/t%d.tif'%i,item,cmap='gray')
    #timg_1 = np.squeeze(conv_t, axis = 3)
    #print(timg_1.shape)
    #timg_2 = np.squeeze(timg_1, axis = 0)
    #print(timg_2.shape)
    #print(timg_2)
    #plt.imshow(timg_2)
    #plt.imsave('/content/drive/My Drive/FCN/plt_img/t0401_3_test.tif',timg_2,cmap='gray')
  
testGenerator("/content/drive/My Drive/new_FCN_0411/data_0521/test_b/")
#results = model.predict_generator(testGene,72,verbose=1)
#saveResult("/content/drive/My Drive/new_FCN_0411/result_yulin/",results,name)
# Out:
# (1, 224, 224, 3)
# b_1.tif_448_0.tif
# (1, 224, 224, 3)
# b_1.tif_448_224.tif
# (1, 224, 224, 3)
# b_1.tif_672_224.tif
# (1, 224, 224, 3)
# b_1.tif_448_448.tif
# (1, 224, 224, 3)
# b_1.tif_448_672.tif
# (1, 224, 224, 3)
# b_1.tif_672_0.tif
# (1, 224, 224, 3)
# b_1.tif_672_448.tif
# (1, 224, 224, 3)
# b_1.tif_224_224.tif
# (1, 224, 224, 3)
# b_1.tif_224_448.tif
# (1, 224, 224, 3)
# b_1.tif_224_672.tif
# (1, 224, 224, 3)
# b_1.tif_672_672.tif
# (1, 224, 224, 3)
# b_1.tif_0_224.tif
# (1, 224, 224, 3)
# b_1.tif_0_672.tif
# (1, 224, 224, 3)
# b_1.tif_0_448.tif
# (1, 224, 224, 3)
# b_1.tif_0_0.tif
# (1, 224, 224, 3)
# b_1.tif_224_0.tif
